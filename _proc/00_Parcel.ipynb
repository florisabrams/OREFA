# %% [raw]
# ---
# description: Parcel object
# output-file: parcel.html
# title: Parcel
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Parcel)
# Out:
# ---
#
# [source](https://github.com/florisabrams/OREFA/blob/main/OREFA/Parcel.py#L9){target="_blank" style="float:right; font-size:smaller"}
#
# ### Parcel
#
# >      Parcel (id, crop, soil, deposition, geom, config=None)
#
# Initialize self.  See help(type(self)) for accurate signature.
