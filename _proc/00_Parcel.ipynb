# %% [raw]
# ---
# description: Parcel object
# output-file: parcel.html
# title: Parcel
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import geopandas as gpd

# %%
#| echo: false
#| output: asis
show_doc(Parcel)
# Out:
# ---
#
# ### Parcel
#
# >      Parcel (id, crop, soil, deposition, geom, config=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
parcel_df = gpd.read_file('/workspaces/OREFA/Assets/Data/aoi.csv')
# Out:
# Index(['field_1', 'id', 'crop', 'soil', 'deposition', 'geom', 'geometry'], dtype='object')

# %% [markdown]
# Import all files and put in Parcel object
# Calculate the concentration of product

# %%
aoi_parcels = []
for parcel in parcel_df.itertuples():
    perceel = Parcel(id=parcel.id, crop=parcel.crop, soil = parcel.soil, deposition=parcel.deposition, geom = parcel.geom)
    perceel.read_config(config_path = '/workspaces/OREFA/Assets/config.ini')
    perceel.product_conc_prediction(time = 1)
    #print(perceel.product_concentration)
    aoi_parcels.append(perceel)
